# %%
import pandas as pd
import numpy as np
import requests
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import time
from time import sleep
from random import randint
import matplotlib as mpl
import matplotlib.pyplot as plt      
import math
import seaborn as sns
from collections import Counter
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
# %matplotlib inline

# %%
anime_name=list()               #x
link_to_anime_page=list()       #x
anime_genres=list()             #x
anime_type=list() #types for example:tv,movie,Original video animation x
anime_aired=list()              #x
anime_members=list()            #x
anime_broadcast=list()          #x
anime_licensors=list()          #x
anime_favorites=list()          #x
anime_popularity=list()         #x
anime_score=list()              #x

df = pd.read_csv('anime_data_final.csv')
print(df)
# Out:
#       Unnamed: 0                                         anime name  \
# 0              0                   Fullmetal Alchemist: Brotherhood
# 1              1                          Bleach: Sennen Kessen-hen
# 2              2                                        Steins;Gate
# 3              3                                           Gintama°
# 4              4         Kaguya-sama wa Kokurasetai: Ultra Romantic
# ...          ...                                                ...
# 4995        4995                                         Ze Tian Ji
# 4996        4996              Twisted Wonderland 1st Anniversary PV
# 4997        4997  Witch Craft Works: Takamiya-kun to Imouto no W...
# 4998        4998                      Wo Shi Da Shenxian 2nd Season
# 4999        4999  Youkai Watch Movie 4: Shadow Side - Oni-ou no ...
#
#          anime_type          anime_aired      anime_members  \
# 0       TV (64 eps)  Apr 2009 - Jul 2010  3,088,738 members
# 1       TV (13 eps)  Oct 2022 - Dec 2022    388,119 members
# 2       TV (24 eps)  Apr 2011 - Sep 2011  2,379,223 members
# 3       TV (51 eps)  Apr 2015 - Mar 2016    577,775 members
# 4       TV (13 eps)  Apr 2022 - Jun 2022    755,828 members
# ...             ...                  ...                ...
# 4995   ONA (13 eps)  Jul 2015 - Dec 2015      7,822 members
# 4996    ONA (1 eps)  Mar 2021 - Mar 2021      1,067 members
# 4997    OVA (1 eps)  Jan 2015 - Jan 2015     33,515 members
# 4998   ONA (16 eps)  Feb 2021 - Jun 2021      1,026 members
# 4999  Movie (1 eps)  Dec 2017 - Dec 2017      1,986 members
#
#                                        anime_genres  \
# 0     ['Genres: Action, Adventure, Drama, Fantasy']
# 1            ['Genres: Action, Adventure, Fantasy']
# 2               ['Genres: Drama, Sci-Fi, Suspense']
# 3                ['Genres: Action, Comedy, Sci-Fi']
# 4                       ['Genres: Comedy, Romance']
# ...                                             ...
# 4995                  ['Genres: Action, Adventure']
# 4996                                             []
# 4997          ['Genres: Adventure, Comedy, Sci-Fi']
# 4998       ['Genres: Action, Horror, Supernatural']
# 4999             ['Genres: Action, Sci-Fi, Sports']
#
#                                anime_broadcast  \
# 0        ['Broadcast: Sundays at 17:00 (JST)']
# 1       ['Broadcast: Tuesdays at 00:00 (JST)']
# 2     ['Broadcast: Wednesdays at 02:05 (JST)']
# 3     ['Broadcast: Wednesdays at 18:00 (JST)']
# 4      ['Broadcast: Saturdays at 00:00 (JST)']
# ...                                        ...
# 4995    ['Broadcast: Tuesdays at 18:30 (JST)']
# 4996   ['Broadcast: Saturdays at 23:00 (JST)']
# 4997    ['Broadcast: Tuesdays at 02:12 (JST)']
# 4998                                        []
# 4999  ['Broadcast: Wednesdays at 00:56 (JST)']
#
#                                     anime_licensors         anime_favorites  \
# 0     ['Licensors: Funimation, Aniplex of America']  ['Favorites: 213,309']
# 1                          ['Licensors: VIZ Media']   ['Favorites: 15,729']
# 2                         ['Licensors: Funimation']  ['Favorites: 179,519']
# 3            ['Licensors: Funimation, Crunchyroll']   ['Favorites: 15,534']
# 4                 ['Licensors: Aniplex of America']   ['Favorites: 27,176']
# ...                                             ...                     ...
# 4995            ['Licensors: Bandai Entertainment']        ['Favorites: 3']
# 4996              ['Licensors: Aniplex of America']      ['Favorites: 227']
# 4997                      ['Licensors: Funimation']      ['Favorites: 230']
# 4998            ['Licensors: None found, add some']       ['Favorites: 13']
# 4999            ['Licensors: None found, add some']        ['Favorites: 4']
#
#             anime_popularity                                   anime_score  \
# 0         ['Popularity: #3']  ['Score: 9.111 (scored by 1,963,910 users)']
# 1       ['Popularity: #526']    ['Score: 9.101 (scored by 170,485 users)']
# 2        ['Popularity: #13']  ['Score: 9.081 (scored by 1,304,594 users)']
# 3       ['Popularity: #337']    ['Score: 9.071 (scored by 231,368 users)']
# 4       ['Popularity: #226']    ['Score: 9.071 (scored by 404,798 users)']
# ...                      ...                                           ...
# 4995  ['Popularity: #10639']        ['Score: 6.801 (scored by 465 users)']
# 4996   ['Popularity: #3059']     ['Score: 6.791 (scored by 15,574 users)']
# 4997   ['Popularity: #2377']     ['Score: 6.791 (scored by 30,671 users)']
# 4998   ['Popularity: #5866']      ['Score: 6.791 (scored by 2,463 users)']
# 4999   ['Popularity: #6267']      ['Score: 6.791 (scored by 3,927 users)']
#
#                                      link_to_anime_page
# 0     https://myanimelist.net/anime/5114/Fullmetal_A...
# 1     https://myanimelist.net/anime/41467/Bleach__Se...
# 2        https://myanimelist.net/anime/9253/Steins_Gate
# 3     https://myanimelist.net/anime/28977/Gintama%C2%B0
# 4     https://myanimelist.net/anime/43608/Kaguya-sam...
# ...                                                 ...
# 4995     https://myanimelist.net/anime/31838/Ze_Tian_Ji
# 4996  https://myanimelist.net/anime/48952/Twisted_Wo...
# 4997  https://myanimelist.net/anime/22117/Witch_Craf...
# 4998  https://myanimelist.net/anime/48369/Wo_Shi_Da_...
# 4999  https://myanimelist.net/anime/34471/Youkai_Wat...
#
# [5000 rows x 12 columns]

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"

anime_genres=list() 
anime_source=list()
anime_broadcast=list()     
anime_licensors=list()     
anime_favorites=list()
anime_popularity=list()    
anime_score=list()         

for x in range(5000):
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    
    anime_genres_temp=list()
    matches1=driver.find_elements('xpath','//*[text()="Genres:"]')
    for match1 in matches1:
        td_p_input1 = match1.find_elements('xpath','..')
        if td_p_input1[0].text != "":
            anime_genres_temp.append(td_p_input1[0].text)
    anime_genres.append(anime_genres_temp)

    anime_source_temp=list()
    matches2=driver.find_elements('xpath','//*[text()="Source:"]')
    for match2 in matches2:
        td_p_input2 = match2.find_elements('xpath','..')
        if td_p_input2[0].text != "":
            anime_source_temp.append(td_p_input2[0].text)
    anime_source.append(anime_source_temp)
    
    anime_broadcast_temp=list() 
    matches3=driver.find_elements('xpath','//*[text()="Broadcast:"]')
    for match3 in matches3:
        td_p_input3 = match3.find_elements('xpath','..')
        if td_p_input3[0].text != "":
            anime_broadcast_temp.append(td_p_input3[0].text)
    anime_broadcast.append(anime_broadcast_temp)
    
    anime_licensors_temp=list()
    matches4=driver.find_elements('xpath','//*[text()="Licensors:"]')
    for match4 in matches4:
        td_p_input4 = match4.find_elements('xpath','..')
        if td_p_input4[0].text != "":
            anime_licensors_temp.append(td_p_input4[0].text)
    anime_licensors.append(anime_licensors_temp)
    
    anime_favorites_temp=list() 
    matches5=driver.find_elements('xpath','//*[text()="Favorites:"]')
    for match5 in matches5:
        td_p_input5 = match5.find_elements('xpath','..')
        if td_p_input5[0].text != "":
            anime_favorites_temp.append(td_p_input5[0].text)
    anime_favorites.append(anime_favorites_temp)
    
    anime_popularity_temp=list()
    matches6=driver.find_elements('xpath','//*[text()="Popularity:"]')
    for match6 in matches6:
        td_p_input6 = match6.find_elements('xpath','..')
        if td_p_input6[0].text != "":
            anime_popularity_temp.append(td_p_input6[0].text)
    anime_popularity.append(anime_popularity_temp)
    
    anime_score_temp=list()
    matches7=driver.find_elements('xpath','//*[text()="Score:"]')
    for match7 in matches7:
        td_p_input7 = match7.find_elements('xpath','..')
        if td_p_input7[0].text != "":
            anime_score_temp.append(td_p_input7[0].text)
    anime_score.append(anime_score_temp)
    
    sleep(randint(3,5))

driver.quit()

df1= pd.DataFrame({'anime_genres':anime_genres,
                'anime_broadcast':anime_broadcast,
                'anime_licensors':anime_licensors,
                'anime_favorites':anime_favorites,
                'anime_popularity':anime_popularity,
                'anime_score':anime_score})
df1.to_csv('anime_data().csv') 
print(df1)

# %%
website = "https://myanimelist.net/topanime.php"
PATH = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(PATH)
driver.get(website)

for x in range(100):
    matches = driver.find_elements('xpath', '//tr/td[2]/div/div[2]/h3/a')
    for match in matches:
        name = match.text
        anime_name.append(name)
        link = match.get_attribute('href')
        link_to_anime_page.append(link)    
    matches1 = driver.find_elements('xpath', '//tr/td/div/div[3]')
    for match1 in matches1:
        all_text = match1.text.splitlines()
        anime_type.append(all_text[0])
        anime_aired.append(all_text[1])
        anime_members.append(all_text[2])                                                        
    try:
        element = WebDriverWait(driver, 30).until(
        EC.presence_of_element_located((By.LINK_TEXT, "Next 50"))
        )
        element.click()
    except:
        driver.quit()

df= pd.DataFrame({'anime name':anime_name,
                'link_to_anime_page':link_to_anime_page,
                'anime_type':anime_type,
                'anime_aired':anime_aired,
                'anime_members':anime_members})
df.to_csv('anime_data(part1).csv')

# %%
anime_name=list()         
link_to_anime_page=list() 
anime_genres=list()       
anime_type=list()
anime_aired=list()        
anime_members=list()      
anime_broadcast=list()    
anime_licensors=list()    
anime_favorites=list()    
anime_popularity=list()   
anime_score=list()        

df1 = pd.read_csv('anime_data(0-1000).csv')
df2 = pd.read_csv('anime_data(1000-2000).csv')
df3 = pd.read_csv('anime_data(2000-3000).csv')
df4 = pd.read_csv('anime_data(3000-4000).csv')
df5 = pd.read_csv('anime_data1(4000-4500).csv')
df6 = pd.read_csv('anime_data4500-5000.csv')
df7 = pd.read_csv('anime_data2.csv')
for x in range(1000):
    anime_genres.append(df1.iloc[x][1])
    anime_broadcast.append(df1.iloc[x][2])
    anime_licensors.append(df1.iloc[x][3])
    anime_favorites.append(df1.iloc[x][4])
    anime_popularity.append(df1.iloc[x][5])
    anime_score.append(df1.iloc[x][6])
for x in range(1000):
    anime_genres.append(df2.iloc[x][1])
    anime_broadcast.append(df2.iloc[x][2])
    anime_licensors.append(df2.iloc[x][3])
    anime_favorites.append(df2.iloc[x][4])
    anime_popularity.append(df2.iloc[x][5])
    anime_score.append(df2.iloc[x][6])
for x in range(1000):
    anime_genres.append(df3.iloc[x][1])
    anime_broadcast.append(df3.iloc[x][2])
    anime_licensors.append(df3.iloc[x][3])
    anime_favorites.append(df3.iloc[x][4])
    anime_popularity.append(df3.iloc[x][5])
    anime_score.append(df3.iloc[x][6])
for x in range(1000):
    anime_genres.append(df4.iloc[x][1])
    anime_broadcast.append(df4.iloc[x][2])
    anime_licensors.append(df4.iloc[x][3])
    anime_favorites.append(df4.iloc[x][4])
    anime_popularity.append(df4.iloc[x][5])
    anime_score.append(df4.iloc[x][6])
for x in range(500):
    anime_genres.append(df5.iloc[x][1])
    anime_broadcast.append(df5.iloc[x][2])
    anime_licensors.append(df5.iloc[x][3])
    anime_favorites.append(df5.iloc[x][4])
    anime_popularity.append(df5.iloc[x][5])
    anime_score.append(df5.iloc[x][6])
for x in range(500):
    anime_genres.append(df6.iloc[x][1])
    anime_broadcast.append(df6.iloc[x][2])
    anime_licensors.append(df6.iloc[x][3])
    anime_favorites.append(df6.iloc[x][4])
    anime_popularity.append(df6.iloc[x][5])
    anime_score.append(df6.iloc[x][6])
for x in range(5000):
    anime_name.append(df7.iloc[x][1])
    link_to_anime_page.append(df7.iloc[x][2])
    anime_type.append(df7.iloc[x][3])
    anime_aired.append(df7.iloc[x][4])
    anime_members.append(df7.iloc[x][5])
    
df1= pd.DataFrame({'anime name':anime_name,
                'anime_type':anime_type,
                'anime_aired':anime_aired,
                'anime_members':anime_members,
                'anime_genres':anime_genres,
                'anime_broadcast':anime_broadcast,
                'anime_licensors':anime_licensors,
                'anime_favorites':anime_favorites,
                'anime_popularity':anime_popularity,
                'anime_score':anime_score,
                'link_to_anime_page':link_to_anime_page,})
df1.to_csv('anime_data_final.csv')
print(df1)

# %%
df1 = pd.DataFrame()
df1 = df[df != '[]']
df1 = df1.dropna()
df1.reset_index(inplace=True)
df1 = df1.drop(df.columns[[0]],axis = 1)
df1.drop('index', inplace=True, axis=1)
print(df1)
df1.to_csv('anime_data_aftercleaning.csv')
# Out:
#                                              anime name     anime_type  \
# 0                      Fullmetal Alchemist: Brotherhood    TV (64 eps)
# 1                             Bleach: Sennen Kessen-hen    TV (13 eps)
# 2                                           Steins;Gate    TV (24 eps)
# 3                                              Gintama°    TV (51 eps)
# 4            Kaguya-sama wa Kokurasetai: Ultra Romantic    TV (13 eps)
# ...                                                 ...            ...
# 1862                                         THE POLiCY  Music (1 eps)
# 1863                                              X OVA    OVA (1 eps)
# 1864                                         Ze Tian Ji   ONA (13 eps)
# 1865  Witch Craft Works: Takamiya-kun to Imouto no W...    OVA (1 eps)
# 1866  Youkai Watch Movie 4: Shadow Side - Oni-ou no ...  Movie (1 eps)
#
#               anime_aired      anime_members  \
# 0     Apr 2009 - Jul 2010  3,088,738 members
# 1     Oct 2022 - Dec 2022    388,119 members
# 2     Apr 2011 - Sep 2011  2,379,223 members
# 3     Apr 2015 - Mar 2016    577,775 members
# 4     Apr 2022 - Jun 2022    755,828 members
# ...                   ...                ...
# 1862  Oct 2022 - Oct 2022        764 members
# 1863  Aug 2001 - Aug 2001     12,611 members
# 1864  Jul 2015 - Dec 2015      7,822 members
# 1865  Jan 2015 - Jan 2015     33,515 members
# 1866  Dec 2017 - Dec 2017      1,986 members
#
#                                        anime_genres  \
# 0     ['Genres: Action, Adventure, Drama, Fantasy']
# 1            ['Genres: Action, Adventure, Fantasy']
# 2               ['Genres: Drama, Sci-Fi, Suspense']
# 3                ['Genres: Action, Comedy, Sci-Fi']
# 4                       ['Genres: Comedy, Romance']
# ...                                             ...
# 1862          ['Genres: Drama, Girls Love, Horror']
# 1863            ['Genres: Action, Comedy, Romance']
# 1864                  ['Genres: Action, Adventure']
# 1865          ['Genres: Adventure, Comedy, Sci-Fi']
# 1866             ['Genres: Action, Sci-Fi, Sports']
#
#                                anime_broadcast  \
# 0        ['Broadcast: Sundays at 17:00 (JST)']
# 1       ['Broadcast: Tuesdays at 00:00 (JST)']
# 2     ['Broadcast: Wednesdays at 02:05 (JST)']
# 3     ['Broadcast: Wednesdays at 18:00 (JST)']
# 4      ['Broadcast: Saturdays at 00:00 (JST)']
# ...                                        ...
# 1862   ['Broadcast: Saturdays at 01:55 (JST)']
# 1863                    ['Broadcast: Unknown']
# 1864    ['Broadcast: Tuesdays at 18:30 (JST)']
# 1865    ['Broadcast: Tuesdays at 02:12 (JST)']
# 1866  ['Broadcast: Wednesdays at 00:56 (JST)']
#
#                                     anime_licensors         anime_favorites  \
# 0     ['Licensors: Funimation, Aniplex of America']  ['Favorites: 213,309']
# 1                          ['Licensors: VIZ Media']   ['Favorites: 15,729']
# 2                         ['Licensors: Funimation']  ['Favorites: 179,519']
# 3            ['Licensors: Funimation, Crunchyroll']   ['Favorites: 15,534']
# 4                 ['Licensors: Aniplex of America']   ['Favorites: 27,176']
# ...                                             ...                     ...
# 1862            ['Licensors: None found, add some']    ['Favorites: 2,556']
# 1863                      ['Licensors: Funimation']      ['Favorites: 884']
# 1864            ['Licensors: Bandai Entertainment']        ['Favorites: 3']
# 1865                      ['Licensors: Funimation']      ['Favorites: 230']
# 1866            ['Licensors: None found, add some']        ['Favorites: 4']
#
#             anime_popularity                                   anime_score  \
# 0         ['Popularity: #3']  ['Score: 9.111 (scored by 1,963,910 users)']
# 1       ['Popularity: #526']    ['Score: 9.101 (scored by 170,485 users)']
# 2        ['Popularity: #13']  ['Score: 9.081 (scored by 1,304,594 users)']
# 3       ['Popularity: #337']    ['Score: 9.071 (scored by 231,368 users)']
# 4       ['Popularity: #226']    ['Score: 9.071 (scored by 404,798 users)']
# ...                      ...                                           ...
# 1862    ['Popularity: #780']    ['Score: 6.801 (scored by 125,962 users)']
# 1863    ['Popularity: #574']    ['Score: 6.801 (scored by 189,569 users)']
# 1864  ['Popularity: #10639']        ['Score: 6.801 (scored by 465 users)']
# 1865   ['Popularity: #2377']     ['Score: 6.791 (scored by 30,671 users)']
# 1866   ['Popularity: #6267']      ['Score: 6.791 (scored by 3,927 users)']
#
#                                      link_to_anime_page
# 0     https://myanimelist.net/anime/5114/Fullmetal_A...
# 1     https://myanimelist.net/anime/41467/Bleach__Se...
# 2        https://myanimelist.net/anime/9253/Steins_Gate
# 3     https://myanimelist.net/anime/28977/Gintama%C2%B0
# 4     https://myanimelist.net/anime/43608/Kaguya-sam...
# ...                                                 ...
# 1862     https://myanimelist.net/anime/53396/THE_POLiCY
# 1863            https://myanimelist.net/anime/595/X_OVA
# 1864     https://myanimelist.net/anime/31838/Ze_Tian_Ji
# 1865  https://myanimelist.net/anime/22117/Witch_Craf...
# 1866  https://myanimelist.net/anime/34471/Youkai_Wat...
#
# [1867 rows x 11 columns]

# %%
anime_scored_by=list()
df2 = df1.copy()
for x in range(len(df2)):
    anime_scored_by.append(df2.iloc[x]["anime_score"])
df2["anime_scored_by"] = anime_scored_by
df2["anime_genres"] = df2["anime_genres"].str[10:-2]
df2["anime_broadcast"] = df2["anime_broadcast"].str[13:-2]
df2["anime_members"] = df2["anime_members"].str[:-7]
df2["anime_licensors"] = df2["anime_licensors"].str[13:-2]
df2["anime_favorites"] = df2["anime_favorites"].str[13:-2]
df2["anime_popularity"] = df2["anime_popularity"].str[15:-2]
df2["anime_score"] = df2["anime_score"].str[9:]
df2["anime_score"] = df2["anime_score"].str[:5]
df2["anime_scored_by"] = df2["anime_scored_by"].str[26:-9]
df2.to_csv('anime_data_aftercleaning2.csv',index=False)
# Out:
#                                              anime name     anime_type  \
# 0                      Fullmetal Alchemist: Brotherhood    TV (64 eps)
# 1                             Bleach: Sennen Kessen-hen    TV (13 eps)
# 2                                           Steins;Gate    TV (24 eps)
# 3                                              Gintama°    TV (51 eps)
# 4            Kaguya-sama wa Kokurasetai: Ultra Romantic    TV (13 eps)
# ...                                                 ...            ...
# 1862                                         THE POLiCY  Music (1 eps)
# 1863                                              X OVA    OVA (1 eps)
# 1864                                         Ze Tian Ji   ONA (13 eps)
# 1865  Witch Craft Works: Takamiya-kun to Imouto no W...    OVA (1 eps)
# 1866  Youkai Watch Movie 4: Shadow Side - Oni-ou no ...  Movie (1 eps)
#
#               anime_aired anime_members                       anime_genres  \
# 0     Apr 2009 - Jul 2010    3,088,738   Action, Adventure, Drama, Fantasy
# 1     Oct 2022 - Dec 2022      388,119          Action, Adventure, Fantasy
# 2     Apr 2011 - Sep 2011    2,379,223             Drama, Sci-Fi, Suspense
# 3     Apr 2015 - Mar 2016      577,775              Action, Comedy, Sci-Fi
# 4     Apr 2022 - Jun 2022      755,828                     Comedy, Romance
# ...                   ...           ...                                ...
# 1862  Oct 2022 - Oct 2022          764           Drama, Girls Love, Horror
# 1863  Aug 2001 - Aug 2001       12,611             Action, Comedy, Romance
# 1864  Jul 2015 - Dec 2015        7,822                   Action, Adventure
# 1865  Jan 2015 - Jan 2015       33,515           Adventure, Comedy, Sci-Fi
# 1866  Dec 2017 - Dec 2017        1,986              Action, Sci-Fi, Sports
#
#                 anime_broadcast                 anime_licensors  \
# 0        Sundays at 17:00 (JST)  Funimation, Aniplex of America
# 1       Tuesdays at 00:00 (JST)                       VIZ Media
# 2     Wednesdays at 02:05 (JST)                      Funimation
# 3     Wednesdays at 18:00 (JST)         Funimation, Crunchyroll
# 4      Saturdays at 00:00 (JST)              Aniplex of America
# ...                         ...                             ...
# 1862   Saturdays at 01:55 (JST)            None found, add some
# 1863                    Unknown                      Funimation
# 1864    Tuesdays at 18:30 (JST)            Bandai Entertainment
# 1865    Tuesdays at 02:12 (JST)                      Funimation
# 1866  Wednesdays at 00:56 (JST)            None found, add some
#
#      anime_favorites anime_popularity anime_score  \
# 0            213,309                3       9.111
# 1             15,729              526       9.101
# 2            179,519               13       9.081
# 3             15,534              337       9.071
# 4             27,176              226       9.071
# ...              ...              ...         ...
# 1862           2,556              780       6.801
# 1863             884              574       6.801
# 1864               3            10639       6.801
# 1865             230             2377       6.791
# 1866               4             6267       6.791
#
#                                      link_to_anime_page anime_scored_by
# 0     https://myanimelist.net/anime/5114/Fullmetal_A...       1,963,910
# 1     https://myanimelist.net/anime/41467/Bleach__Se...         170,485
# 2        https://myanimelist.net/anime/9253/Steins_Gate       1,304,594
# 3     https://myanimelist.net/anime/28977/Gintama%C2%B0         231,368
# 4     https://myanimelist.net/anime/43608/Kaguya-sam...         404,798
# ...                                                 ...             ...
# 1862     https://myanimelist.net/anime/53396/THE_POLiCY         125,962
# 1863            https://myanimelist.net/anime/595/X_OVA         189,569
# 1864     https://myanimelist.net/anime/31838/Ze_Tian_Ji             465
# 1865  https://myanimelist.net/anime/22117/Witch_Craf...          30,671
# 1866  https://myanimelist.net/anime/34471/Youkai_Wat...           3,927
#
# [1867 rows x 12 columns]

# %%
df2['anime_members']=df2['anime_members'].str.replace(',','')
df2['anime_scored_by']=df2['anime_scored_by'].str.replace(',','')
df2['anime_favorites']=df2['anime_favorites'].str.replace(',','')

# %%
df2['anime_members']= df2["anime_members"].astype(int)
df2['anime_favorites']= df2["anime_favorites"].astype(int)
df2['anime_popularity']= df2["anime_popularity"].astype(int)
df2['anime_scored_by']= df2["anime_scored_by"].astype(int)
df2['anime_score']= df2["anime_score"].astype(float)

# %%
df2.to_csv('anime_data_aftercleaning3.csv',index=False)

# %%
df2 = pd.read_csv('anime_data_aftercleaning3.csv')
df2
# Out:
#                                              anime name     anime_type  \
# 0                      Fullmetal Alchemist: Brotherhood    TV (64 eps)
# 1                             Bleach: Sennen Kessen-hen    TV (13 eps)
# 2                                           Steins;Gate    TV (24 eps)
# 3                                              Gintama°    TV (51 eps)
# 4            Kaguya-sama wa Kokurasetai: Ultra Romantic    TV (13 eps)
# ...                                                 ...            ...
# 1862                                         THE POLiCY  Music (1 eps)
# 1863                                              X OVA    OVA (1 eps)
# 1864                                         Ze Tian Ji   ONA (13 eps)
# 1865  Witch Craft Works: Takamiya-kun to Imouto no W...    OVA (1 eps)
# 1866  Youkai Watch Movie 4: Shadow Side - Oni-ou no ...  Movie (1 eps)
#
#               anime_aired  anime_members                       anime_genres  \
# 0     Apr 2009 - Jul 2010        3088738  Action, Adventure, Drama, Fantasy
# 1     Oct 2022 - Dec 2022         388119         Action, Adventure, Fantasy
# 2     Apr 2011 - Sep 2011        2379223            Drama, Sci-Fi, Suspense
# 3     Apr 2015 - Mar 2016         577775             Action, Comedy, Sci-Fi
# 4     Apr 2022 - Jun 2022         755828                    Comedy, Romance
# ...                   ...            ...                                ...
# 1862  Oct 2022 - Oct 2022            764          Drama, Girls Love, Horror
# 1863  Aug 2001 - Aug 2001          12611            Action, Comedy, Romance
# 1864  Jul 2015 - Dec 2015           7822                  Action, Adventure
# 1865  Jan 2015 - Jan 2015          33515          Adventure, Comedy, Sci-Fi
# 1866  Dec 2017 - Dec 2017           1986             Action, Sci-Fi, Sports
#
#                 anime_broadcast                 anime_licensors  \
# 0        Sundays at 17:00 (JST)  Funimation, Aniplex of America
# 1       Tuesdays at 00:00 (JST)                       VIZ Media
# 2     Wednesdays at 02:05 (JST)                      Funimation
# 3     Wednesdays at 18:00 (JST)         Funimation, Crunchyroll
# 4      Saturdays at 00:00 (JST)              Aniplex of America
# ...                         ...                             ...
# 1862   Saturdays at 01:55 (JST)            None found, add some
# 1863                    Unknown                      Funimation
# 1864    Tuesdays at 18:30 (JST)            Bandai Entertainment
# 1865    Tuesdays at 02:12 (JST)                      Funimation
# 1866  Wednesdays at 00:56 (JST)            None found, add some
#
#       anime_favorites  anime_popularity  anime_score  \
# 0              213309                 3        9.111
# 1               15729               526        9.101
# 2              179519                13        9.081
# 3               15534               337        9.071
# 4               27176               226        9.071
# ...               ...               ...          ...
# 1862             2556               780        6.801
# 1863              884               574        6.801
# 1864                3             10639        6.801
# 1865              230              2377        6.791
# 1866                4              6267        6.791
#
#                                      link_to_anime_page  anime_scored_by  \
# 0     https://myanimelist.net/anime/5114/Fullmetal_A...          1963910
# 1     https://myanimelist.net/anime/41467/Bleach__Se...           170485
# 2        https://myanimelist.net/anime/9253/Steins_Gate          1304594
# 3     https://myanimelist.net/anime/28977/Gintama%C2%B0           231368
# 4     https://myanimelist.net/anime/43608/Kaguya-sam...           404798
# ...                                                 ...              ...
# 1862     https://myanimelist.net/anime/53396/THE_POLiCY           125962
# 1863            https://myanimelist.net/anime/595/X_OVA           189569
# 1864     https://myanimelist.net/anime/31838/Ze_Tian_Ji              465
# 1865  https://myanimelist.net/anime/22117/Witch_Craf...            30671
# 1866  https://myanimelist.net/anime/34471/Youkai_Wat...             3927
#
#      anime_season_aired anime_year_aired
# 0                spring            2009
# 1                  fall            2022
# 2                spring            2011
# 3                spring            2015
# 4                spring            2022
# ...                 ...              ...
# 1862               fall            2022
# 1863               fall            2001
# 1864             summer            2015
# 1865             winter            2015
# 1866               fall            2017
#
# [1867 rows x 14 columns]

# %%
# EDA_visualization
anime_genres_split=list()
df = pd.read_csv('anime_data_aftercleaning1.csv')
df4 = df["anime_genres"].str.split(', ')
for x in range(len(df4)):
    temp_list = df4[x]
    for str1 in range(len(df4[x])):
            anime_genres_split.append(temp_list[str1])
df9= pd.DataFrame({'genre':anime_genres_split})
data = df9.value_counts()
data
# Out:
# genre
# Comedy           851
# Action           772
# Fantasy          571
# Drama            541
# Adventure        525
# Romance          488
# Sci-Fi           439
# Supernatural     328
# Mystery          209
# Slice of Life    199
# Ecchi            125
# Sports            71
# Horror            66
# Suspense          53
# Award Winning     52
# Gourmet           35
# Girls Love        27
# Boys Love         20
# Avant Garde        8
# dtype: int64

# %%
ax = data.plot.pie(legend=True,  ylabel='', labeldistance=None, title="genres frequency")
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.show() #decending order
#df2.anime_score.mean()

# %%
ax = data.plot.bar(ylabel='', title="genres frequency")
plt.show() #decending order

# %%
df2.isnull().sum()
# Out:
# anime name            0
# anime_type            0
# anime_aired           0
# anime_members         0
# anime_genres          0
# anime_broadcast       0
# anime_licensors       0
# anime_favorites       0
# anime_popularity      0
# anime_score           0
# link_to_anime_page    0
# anime_scored_by       0
# dtype: int64

# %%
anime_season_aired=list()
anime_year_aired=list()
for x in range(len(df2)):
    if (df2.iloc[x]['anime_aired'][:3]==('Jan'or'Feb'or'Mer')):
        anime_season_aired.append('winter')
    elif (df2.iloc[x]['anime_aired'][:3]==('Apr'or'May'or'Jun')):
          anime_season_aired.append('spring')
    elif (df2.iloc[x]['anime_aired'][:3]==('Jul'or'Aug'or'Sep')):
          anime_season_aired.append('summer')
    else: anime_season_aired.append('fall')
df2['anime_season_aired']=anime_season_aired
for x in range(len(df2)):
    anime_year_aired.append(df2.iloc[x]['anime_aired'][4:9])
df2['anime_year_aired']=anime_year_aired
df2 = df2[df2['anime_year_aired'] != ' - 20']
df2['anime_year_aired']= df2["anime_year_aired"].astype(int)
# Out:
# C:\Users\Shay\AppData\Local\Temp\ipykernel_27060\3823393313.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['anime_year_aired']= df2["anime_year_aired"].astype(int)

# %%
sns.relplot(x='anime_members',y='anime_score',hue='anime_season_aired',data=df2)
#df2.anime_score.mean()

# %%
sns.relplot(x='anime_members',y='anime_scored_by',hue='anime_season_aired',data=df2)

# %%
sns.relplot(x='anime_year_aired',y='anime_scored_by',hue='anime_season_aired',data=df2)
df2.anime_season_aired.value_counts()
# Out:
# fall      794
# spring    489
# winter    303
# summer    280
# Name: anime_season_aired, dtype: int64

# %%
corelation = df2.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df2)

# %%
df3 = df2[['anime_members','anime_score','anime_favorites','anime_popularity','anime_scored_by']].copy()
#linear regression
TRAINING_FEATURES = df3.columns[df3.columns != 'anime_score']
TARGET_FEATURES = 'anime_score'

x= df3[TRAINING_FEATURES]
y= df3[TARGET_FEATURES]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (1399, 4) (1399,)
# (467, 4) (467,)

# %%
linearM = linear_model.LinearRegression()
linearM1 = linearM.fit(x_train,y_train)
lrm_pred = linearM.predict(x_test)

# %%
lrm_pred
# Out:
# array([7.23816505, 7.20793518, 7.62443389, 7.6757827 , 7.04612494,
#        7.58549574, 7.14571607, 7.07226453, 7.37625901, 7.5498159 ,
#        7.58608153, 7.48305728, 7.34599575, 7.88733138, 7.52437158,
#        7.34304132, 7.24337146, 7.35628026, 7.18031029, 7.23864998,
#        7.24923335, 7.45652193, 8.00983937, 7.68911972, 7.59557401,
#        7.36043094, 7.2491274 , 7.12549767, 7.03185405, 7.28372519,
#        7.08795128, 7.00980797, 7.24763839, 7.77154822, 7.04610869,
#        7.61953601, 7.74114617, 7.19988175, 7.51352951, 7.51156951,
#        7.40229342, 7.32235362, 7.87685042, 7.25924387, 7.35121753,
#        7.57399921, 7.58326273, 7.7380812 , 7.27027296, 7.35812366,
#        7.31699784, 7.63430001, 7.29385685, 7.51828845, 7.31236947,
#        7.3849546 , 7.26646479, 7.29266807, 7.0690637 , 8.05881203,
#        7.17228014, 7.68773172, 7.54532267, 7.90151633, 7.27822817,
#        8.19338707, 7.91704876, 7.38063516, 7.53326714, 7.34270537,
#        7.58842526, 8.60266251, 7.31227073, 7.42184681, 7.82487958,
#        7.57947474, 7.49071919, 6.58866941, 7.55448914, 7.22435077,
#        7.48357496, 7.22469336, 7.28347589, 7.65397548, 7.52424707,
#        7.39179227, 7.71610745, 7.40622886, 7.44095263, 7.84299114,
#        7.1223866 , 7.22472436, 7.26861914, 7.61461163, 7.72728052,
#        7.52386863, 7.20051909, 7.26561778, 7.16701385, 7.58462319,
#        7.29014901, 7.67186348, 9.75277332, 7.70299377, 7.42642896,
#        7.46371516, 7.36271191, 7.46244165, 7.51817978, 7.48292339,
#        7.49549419, 7.28035112, 8.00833479, 7.43353098, 7.92538555,
#        7.41016547, 7.43684218, 7.61701066, 7.89737469, 7.50547998,
#        7.59226891, 7.50790268, 7.50581279, 6.97783468, 7.3269255 ,
#        7.66911669, 7.30229707, 7.40448902, 7.26482105, 7.10610766,
#        7.21835898, 7.28773044, 7.58904793, 7.15317016, 8.04115069,
#        7.35715413, 7.37465214, 8.26279189, 7.54349407, 7.20178676,
#        7.67088748, 7.83820734, 7.25699985, 7.38795877, 7.32026694,
#        7.30143205, 7.42916165, 7.31117626, 7.66840159, 7.02467531,
#        6.97596648, 7.28391968, 7.19188616, 7.31430709, 7.60612356,
#        7.83711419, 7.14380007, 8.57324139, 7.87105095, 7.04772121,
#        7.29810272, 7.53087418, 7.39960923, 6.99466807, 7.60238084,
#        7.48495392, 7.40744462, 7.39048484, 7.57862797, 7.35987149,
#        7.16711102, 7.37209039, 7.77083512, 7.27196313, 7.55777861,
#        7.12389264, 7.47588965, 7.2762251 , 7.47551996, 7.50245091,
#        7.48762484, 7.2421069 , 7.70224156, 7.01154513, 7.33816065,
#        7.57338235, 7.81781641, 7.56927799, 7.43689787, 7.54030121,
#        7.72024195, 7.33660384, 7.74295318, 6.97915137, 7.74676388,
#        8.15241502, 7.26316937, 7.3910132 , 7.03317544, 7.59946136,
#        7.42220231, 7.57941579, 7.67589848, 7.24667198, 6.9758316 ,
#        7.52564987, 7.31637703, 7.53114571, 7.51464763, 7.33468578,
#        7.6273192 , 7.48362356, 7.54883049, 7.59858616, 7.19208755,
#        7.54382948, 7.24217761, 7.32639849, 7.25240812, 7.71039553,
#        7.57269349, 7.28284257, 7.23381251, 7.56452736, 7.78885393,
#        7.61708919, 7.39752254, 7.36568922, 7.26817702, 7.36934429,
#        7.67503422, 7.49500191, 7.75175568, 8.20024922, 7.48234848,
#        7.2902538 , 7.38451928, 7.35733552, 7.36381136, 7.13900719,
#        7.61511473, 7.30090132, 7.3597289 , 7.30514447, 7.39647226,
#        7.24135306, 7.49333231, 7.45806842, 7.74342802, 7.31901008,
#        7.00771386, 7.5423032 , 7.23315328, 7.27769198, 7.70399241,
#        7.47581428, 7.12320966, 7.54434406, 7.77303245, 7.20461773,
#        7.54629079, 7.66322835, 8.26412858, 7.40906813, 7.59383512,
#        6.99682024, 7.5222062 , 7.25292999, 8.2509008 , 7.52378836,
#        7.12174663, 7.92079652, 7.0042573 , 7.5027125 , 7.35663577,
#        7.13213548, 7.31185518, 7.36464157, 7.66921817, 8.85484346,
#        7.58184436, 7.31053144, 7.26164279, 8.05867235, 7.6506061 ,
#        7.58362655, 7.38623296, 7.47184503, 7.78724278, 7.35100251,
#        7.70951318, 7.31875149, 7.28065138, 7.67151707, 7.42380182,
#        7.24204615, 7.22668707, 7.43531577, 7.13070005, 7.93039062,
#        7.68145614, 7.59270531, 7.68248009, 7.61305626, 7.53696128,
#        7.41501716, 7.47925448, 7.60073282, 7.46037773, 7.49120476,
#        7.24750025, 7.36444099, 7.33780451, 7.60884231, 7.94280257,
#        7.70453031, 7.76474017, 7.08486108, 7.34285068, 7.47772732,
#        7.27338436, 7.22692384, 7.43161234, 7.31599885, 7.1245907 ,
#        7.42341894, 7.44037913, 7.18865589, 7.37326278, 7.64141977,
#        7.67765537, 7.77223104, 7.66364131, 7.37830372, 7.34007911,
#        7.66754882, 7.18457368, 7.23223195, 7.00294649, 7.0465414 ,
#        7.48851808, 7.51825724, 7.63851534, 7.41314069, 7.44393504,
#        6.99670076, 7.45211884, 7.33780561, 7.26663947, 7.46910896,
#        7.51105457, 7.32999596, 8.75744657, 7.42523776, 7.5587028 ,
#        7.11569781, 7.43219488, 7.43802508, 7.00284769, 7.28483282,
#        7.25513921, 7.42107079, 7.32907472, 7.30663636, 7.47739642,
#        7.28101677, 7.60826164, 7.29388504, 7.25944595, 7.07680548,
#        7.49297706, 7.05296648, 7.71210784, 7.30940477, 7.46020733,
#        7.56575105, 8.01682614, 7.44075626, 7.34263848, 7.72761917,
#        7.45916459, 7.20051544, 7.44369672, 7.61483782, 7.32703113,
#        7.19183971, 7.51033857, 7.80128254, 7.52880111, 7.01454483,
#        8.26781809, 7.33450953, 7.43783241, 7.26226226, 7.45887373,
#        7.61948123, 7.27708657, 7.7862077 , 7.33217195, 7.54268012,
#        7.25866586, 7.32199838, 7.30966818, 7.33562705, 7.68859146,
#        8.54700711, 7.28498105, 7.17353165, 7.53554884, 7.26430722,
#        7.4006673 , 7.43379581, 6.98185251, 7.44612309, 7.26247252,
#        7.37190559, 7.51145631, 7.40756742, 7.54315247, 7.84152558,
#        7.24705817, 7.22440786, 7.43146556, 7.3060751 , 7.39954032,
#        7.41836668, 7.49976572, 7.71112924, 7.45754504, 7.27757415,
#        7.30804903, 7.47882761, 7.43713056, 7.71422425, 7.98606306,
#        7.70827766, 7.0646222 , 7.47354826, 7.0940509 , 7.58151494,
#        7.44462925, 7.57931766, 7.4014544 , 7.15591221, 7.39592408,
#        7.37946116, 7.92998045, 7.33012365, 7.51007358, 7.51351229,
#        7.42884891, 7.38139609, 7.26672978, 7.59656144, 7.10928901,
#        7.27709721, 7.54854874, 7.28169107, 7.21148143, 7.50282024,
#        7.76201121, 7.49053395, 7.52045474, 7.79270835, 7.39837752,
#        7.65759821, 8.46419193])

# %%
print("score: ",linearM.score(x_test,y_test))
# Out:
# score:  0.41303997095102485

# %%
pred_and_act = pd.DataFrame(x_test)
pred_and_act['anime_act_score'] = y_test
pred_and_act['anime_pred_score'] = lrm_pred
pred_and_act = pred_and_act.reset_index()

# %%
x_test = pred_and_act.columns[pred_and_act.columns != 'index']
pred_and_act[x_test]
# Out:
#      anime_members  anime_favorites  anime_popularity  anime_scored_by  \
# 0              650               61              4550             6603
# 1            10326              161              5822             3348
# 2           360019             1663               578           161317
# 3           683332             2610               261           370704
# 4             2732                4              9530              548
# ..             ...              ...               ...              ...
# 462         177291              865              1203            67274
# 463         729373             6579               236           367737
# 464          83734              488              2098            39532
# 465         256096             4103               839            80832
# 466        1493330            41983                66           751241
#
#      anime_act_score  anime_pred_score
# 0              6.911          7.238165
# 1              7.521          7.207935
# 2              7.661          7.624434
# 3              7.571          7.675783
# 4              7.091          7.046125
# ..               ...               ...
# 462            7.231          7.520455
# 463            7.441          7.792708
# 464            7.571          7.398378
# 465            8.011          7.657598
# 466            8.141          8.464192
#
# [467 rows x 6 columns]

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
anime_source=list()
for x in range(3):
    anime_source_temp=list()
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    matches=driver.find_elements('xpath','//*[text()="Source:"]')
    for match in matches:
        td_p_input = match.find_elements('xpath','..')
        if td_p_input[0].text != "":
            anime_source_temp.append(td_p_input[0].text)
    anime_source.append(anime_source_temp)
    sleep(randint(1,3))
print(anime_source)
driver.quit()

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
anime_broadcast=list()
for x in range(3):
    anime_broadcast_temp=list()
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    matches=driver.find_elements('xpath','//*[text()="Broadcast:"]')
    for match in matches:
        td_p_input2 = match.find_elements('xpath','..')
        if td_p_input2[0].text != "":
            anime_broadcast_temp.append(td_p_input2[0].text)
    anime_broadcast.append(anime_broadcast_temp)
    sleep(randint(1,3))
print(anime_broadcast)
driver.quit()

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
anime_Licensors=list()
for x in range(3):
    anime_Licensors_temp=list()
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    matches=driver.find_elements('xpath','//*[text()="Licensors:"]')
    for match in matches:
        td_p_input4 = match.find_elements('xpath','..')
        if td_p_input4[0].text != "":
            anime_Licensors_temp.append(td_p_input4[0].text)
    anime_Licensors.append(anime_Licensors_temp)
    sleep(randint(1,3))
print(anime_Licensors)
driver.quit()

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
anime_favorites=list()
for x in range(3):
    anime_favorites_temp=list() 
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    matches5=driver.find_elements('xpath','//*[text()="Favorites:"]')
    for match5 in matches5:
        td_p_input5 = match5.find_elements('xpath','..')
        if td_p_input5[0].text != "":
            anime_favorites_temp.append(td_p_input5[0].text)
    anime_favorites.append(anime_favorites_temp)
    sleep(randint(1,3))
print(anime_favorites)
driver.quit()

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
anime_popularity=list()
for x in range(3):
    anime_popularity_temp=list()
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    matches6=driver.find_elements('xpath','//*[text()="Popularity:"]')
    for match6 in matches6:
        td_p_input6 = match6.find_elements('xpath','..')
        if td_p_input6[0].text != "":
            anime_popularity_temp.append(td_p_input6[0].text)
    anime_popularity.append(anime_popularity_temp)
    sleep(randint(1,3))
print(anime_popularity)
driver.quit()

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
anime_score=list()
for x in range(3):
    anime_score_temp=list()
    website=df.iloc[x][2]
    driver = webdriver.Chrome(PATH)
    driver.get(website)
    matches7=driver.find_elements('xpath','//*[text()="Score:"]')
    for match7 in matches7:
        td_p_input7 = match7.find_elements('xpath','..')
        if td_p_input7[0].text != "":
            anime_score_temp.append(td_p_input7[0].text)
    anime_score.append(anime_score_temp)
    sleep(randint(1,3))
print(anime_score)
driver.quit()
